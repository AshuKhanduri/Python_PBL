# %%
from sklearn.preprocessing import MinMaxScaler , StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Real_House_Data.csv")
df
# Out:
#       Property_Area  Bedrooms  Bathrooms  Floors  Year_Built  Property_Age  \
# 0       2684.821829         5          5       2        2018             7
# 1       1772.507662         1          1       1        1970            55
# 2       1655.959623         2          1       1        2015            10
# 3       1655.979127         1          1       1        1976            49
# 4       4879.446067         3          2       3        1999            26
# ...             ...       ...        ...     ...         ...           ...
# 9995    2302.741825         2          2       1        1994            31
# 9996    1373.561786         3          3       2        1994            31
# 9997    1191.319333         2          2       2        2022             3
# 9998    2811.384485         6          5       1        1970            55
# 9999     802.612274         1          1       2        1972            53
#
#      Renovation_Status     Lot_Size  Distance_to_City_Center  \
# 0                  Yes  3776.225833                33.354414
# 1                   No  3343.248191                21.896193
# 2                   No  2856.909759                25.358405
# 3                  Yes  2998.753552                22.062582
# 4                   No  5373.625371                22.449431
# ...                ...          ...                      ...
# 9995                No  3766.541599                10.708116
# 9996                No  2271.349068                11.949866
# 9997                No  2748.265662                23.944225
# 9998                No          NaN                 7.170758
# 9999               Yes  1385.413483                18.927714
#
#       Neighborhood_Quality_Score  ...      Property_Type  \
# 0                              8  ...  Independent House
# 1                              5  ...          Apartment
# 2                              2  ...          Apartment
# 3                              6  ...          Apartment
# 4                              2  ...              Villa
# ...                          ...  ...                ...
# 9995                           9  ...              Villa
# 9996                           4  ...              Villa
# 9997                           2  ...  Independent House
# 9998                           8  ...              Villa
# 9999                           7  ...  Independent House
#
#       Construction_Quality_Rating  Energy_Efficiency_Score  \
# 0                               2                      NaN
# 1                               5                      5.0
# 2                               8                      2.0
# 3                               5                     10.0
# 4                               5                      9.0
# ...                           ...                      ...
# 9995                            9                      3.0
# 9996                            3                     10.0
# 9997                            8                      2.0
# 9998                            1                      1.0
# 9999                            8                      4.0
#
#       Water_Supply_Reliability  Electricity_Supply_Reliability  \
# 0                            4                               5
# 1                            3                               5
# 2                            3                               5
# 3                            9                               2
# 4                            1                              10
# ...                        ...                             ...
# 9995                         7                               6
# 9996                         9                               3
# 9997                        10                               4
# 9998                         1                               8
# 9999                        10                               5
#
#       Internet_Availability_Score Green_Space_Availability_Index  \
# 0                               8                      51.585174
# 1                               8                      36.729241
# 2                              10                      20.020779
# 3                               4                      40.894197
# 4                               2                      22.463846
# ...                           ...                            ...
# 9995                            2                      72.799026
# 9996                            8                      25.805114
# 9997                            8                       0.000000
# 9998                            7                      54.362379
# 9999                            9                      50.928561
#
#       Flood_Risk_Index  Noise_Pollution_Level         Price
# 0            42.269855              51.872234  1.203248e+07
# 1            66.331214              66.489083  7.425842e+06
# 2            79.023068              68.119671  5.734560e+06
# 3            53.745498              60.449037  8.258959e+06
# 4            86.873374              61.445164  2.128731e+07
# ...                ...                    ...           ...
# 9995         36.744778              43.506769  1.173157e+07
# 9996         89.150722              66.396883  6.458641e+06
# 9997         91.177488              76.934267  4.891362e+06
# 9998         47.010666              53.486149  1.353664e+07
# 9999         48.380489              54.906311  4.605158e+06
#
# [10000 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# Property_Area                       0
# Bedrooms                            0
# Bathrooms                           0
# Floors                              0
# Year_Built                          0
# Property_Age                        0
# Renovation_Status                   0
# Lot_Size                          500
# Distance_to_City_Center             0
# Neighborhood_Quality_Score          0
# Crime_Rate_Index                    0
# Nearby_School_Rating              500
# Hospital_Proximity_km               0
# Shopping_Center_Proximity_km        0
# Public_Transport_Accessibility      0
# Parking_Availability                0
# Property_Type                       0
# Construction_Quality_Rating         0
# Energy_Efficiency_Score           500
# Water_Supply_Reliability            0
# Electricity_Supply_Reliability      0
# Internet_Availability_Score         0
# Green_Space_Availability_Index    500
# Flood_Risk_Index                    0
# Noise_Pollution_Level               0
# Price                               0
# dtype: int64

# %%
#Lot_Size Fixed
df['Lot_Size'] = df.groupby(['Property_Type', 'Bedrooms'])['Lot_Size'].transform(lambda x: x.fillna(x.mean()))

# %%
#Nearby School Rating Fixed
df['Neighborhood_bin'] = pd.cut(df['Neighborhood_Quality_Score'], bins=5)

df['Nearby_School_Rating'] = df.groupby('Neighborhood_bin' , observed = True)['Nearby_School_Rating'].transform(
    lambda x: x.fillna(x.mean())
)

# %%
#Energy Score Fixed
df['Age_bin'] = pd.cut(df['Property_Age'], bins=5)

df['Energy_Efficiency_Score'] = df.groupby(['Age_bin', 'Construction_Quality_Rating'] , observed = True)['Energy_Efficiency_Score'].transform(
    lambda x: x.fillna(x.mean())
)

# %%
#Green Availability Fixed
df['Distance_bin'] = pd.cut(df['Distance_to_City_Center'], bins=5)

df['Green_Space_Availability_Index'] = df.groupby('Distance_bin' , observed = True)['Green_Space_Availability_Index'].transform(
    lambda x: x.fillna(x.mean())
)

# %%
print(df.isnull().sum())
df_new = df.drop(columns = ['Neighborhood_bin' , 'Age_bin' , 'Distance_bin'])
df_new
# Out:
# Property_Area                     0
# Bedrooms                          0
# Bathrooms                         0
# Floors                            0
# Year_Built                        0
# Property_Age                      0
# Renovation_Status                 0
# Lot_Size                          0
# Distance_to_City_Center           0
# Neighborhood_Quality_Score        0
# Crime_Rate_Index                  0
# Nearby_School_Rating              0
# Hospital_Proximity_km             0
# Shopping_Center_Proximity_km      0
# Public_Transport_Accessibility    0
# Parking_Availability              0
# Property_Type                     0
# Construction_Quality_Rating       0
# Energy_Efficiency_Score           0
# Water_Supply_Reliability          0
# Electricity_Supply_Reliability    0
# Internet_Availability_Score       0
# Green_Space_Availability_Index    0
# Flood_Risk_Index                  0
# Noise_Pollution_Level             0
# Price                             0
# Neighborhood_bin                  0
# Age_bin                           0
# Distance_bin                      0
# dtype: int64
#       Property_Area  Bedrooms  Bathrooms  Floors  Year_Built  Property_Age  \
# 0       2684.821829         5          5       2        2018             7
# 1       1772.507662         1          1       1        1970            55
# 2       1655.959623         2          1       1        2015            10
# 3       1655.979127         1          1       1        1976            49
# 4       4879.446067         3          2       3        1999            26
# ...             ...       ...        ...     ...         ...           ...
# 9995    2302.741825         2          2       1        1994            31
# 9996    1373.561786         3          3       2        1994            31
# 9997    1191.319333         2          2       2        2022             3
# 9998    2811.384485         6          5       1        1970            55
# 9999     802.612274         1          1       2        1972            53
#
#      Renovation_Status     Lot_Size  Distance_to_City_Center  \
# 0                  Yes  3776.225833                33.354414
# 1                   No  3343.248191                21.896193
# 2                   No  2856.909759                25.358405
# 3                  Yes  2998.753552                22.062582
# 4                   No  5373.625371                22.449431
# ...                ...          ...                      ...
# 9995                No  3766.541599                10.708116
# 9996                No  2271.349068                11.949866
# 9997                No  2748.265662                23.944225
# 9998                No  4906.370154                 7.170758
# 9999               Yes  1385.413483                18.927714
#
#       Neighborhood_Quality_Score  ...      Property_Type  \
# 0                              8  ...  Independent House
# 1                              5  ...          Apartment
# 2                              2  ...          Apartment
# 3                              6  ...          Apartment
# 4                              2  ...              Villa
# ...                          ...  ...                ...
# 9995                           9  ...              Villa
# 9996                           4  ...              Villa
# 9997                           2  ...  Independent House
# 9998                           8  ...              Villa
# 9999                           7  ...  Independent House
#
#       Construction_Quality_Rating  Energy_Efficiency_Score  \
# 0                               2                 5.769608
# 1                               5                 5.000000
# 2                               8                 2.000000
# 3                               5                10.000000
# 4                               5                 9.000000
# ...                           ...                      ...
# 9995                            9                 3.000000
# 9996                            3                10.000000
# 9997                            8                 2.000000
# 9998                            1                 1.000000
# 9999                            8                 4.000000
#
#       Water_Supply_Reliability  Electricity_Supply_Reliability  \
# 0                            4                               5
# 1                            3                               5
# 2                            3                               5
# 3                            9                               2
# 4                            1                              10
# ...                        ...                             ...
# 9995                         7                               6
# 9996                         9                               3
# 9997                        10                               4
# 9998                         1                               8
# 9999                        10                               5
#
#       Internet_Availability_Score Green_Space_Availability_Index  \
# 0                               8                      51.585174
# 1                               8                      36.729241
# 2                              10                      20.020779
# 3                               4                      40.894197
# 4                               2                      22.463846
# ...                           ...                            ...
# 9995                            2                      72.799026
# 9996                            8                      25.805114
# 9997                            8                       0.000000
# 9998                            7                      54.362379
# 9999                            9                      50.928561
#
#       Flood_Risk_Index  Noise_Pollution_Level         Price
# 0            42.269855              51.872234  1.203248e+07
# 1            66.331214              66.489083  7.425842e+06
# 2            79.023068              68.119671  5.734560e+06
# 3            53.745498              60.449037  8.258959e+06
# 4            86.873374              61.445164  2.128731e+07
# ...                ...                    ...           ...
# 9995         36.744778              43.506769  1.173157e+07
# 9996         89.150722              66.396883  6.458641e+06
# 9997         91.177488              76.934267  4.891362e+06
# 9998         47.010666              53.486149  1.353664e+07
# 9999         48.380489              54.906311  4.605158e+06
#
# [10000 rows x 26 columns]

# %%
# Basic info
print(df.head())
print(df.info())
print(df.describe())

# Missing values
print(df.isnull().sum())
# Out:
#    Property_Area  Bedrooms  Bathrooms  Floors  Year_Built  Property_Age  \
# 0    2684.821829         5          5       2        2018             7
# 1    1772.507662         1          1       1        1970            55
# 2    1655.959623         2          1       1        2015            10
# 3    1655.979127         1          1       1        1976            49
# 4    4879.446067         3          2       3        1999            26
#
#   Renovation_Status     Lot_Size  Distance_to_City_Center  \
# 0               Yes  3776.225833                33.354414
# 1                No  3343.248191                21.896193
# 2                No  2856.909759                25.358405
# 3               Yes  2998.753552                22.062582
# 4                No  5373.625371                22.449431
#
#    Neighborhood_Quality_Score  ...  Water_Supply_Reliability  \
# 0                           8  ...                         4
# 1                           5  ...                         3
# 2                           2  ...                         3
# 3                           6  ...                         9
# 4                           2  ...                         1
#
#    Electricity_Supply_Reliability  Internet_Availability_Score  \
# 0                               5                            8
# 1                               5                            8
# 2                               5                           10
# 3                               2                            4
# 4                              10                            2
#
#    Green_Space_Availability_Index  Flood_Risk_Index  Noise_Pollution_Level  \
# 0                       51.585174         42.269855              51.872234
# 1                       36.729241         66.331214              66.489083
# 2                       20.020779         79.023068              68.119671
# 3                       40.894197         53.745498              60.449037
# 4                       22.463846         86.873374              61.445164
#
#           Price  Neighborhood_bin        Age_bin      Distance_bin
# 0  1.203248e+07        (6.4, 8.2]  (0.946, 11.8]  (31.997, 39.995]
# 1  7.425842e+06        (4.6, 6.4]   (44.2, 55.0]  (16.001, 23.999]
# 2  5.734560e+06      (0.991, 2.8]  (0.946, 11.8]  (23.999, 31.997]
# 3  8.258959e+06        (4.6, 6.4]   (44.2, 55.0]  (16.001, 23.999]
# 4  2.128731e+07      (0.991, 2.8]   (22.6, 33.4]  (16.001, 23.999]
#
# [5 rows x 29 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Property_Area                   10000 non-null  float64
#  1   Bedrooms                        10000 non-null  int64
#  2   Bathrooms                       10000 non-null  int64
#  3   Floors                          10000 non-null  int64
#  4   Year_Built                      10000 non-null  int64
#  5   Property_Age                    10000 non-null  int64
#  6   Renovation_Status               10000 non-null  object
#  7   Lot_Size                        10000 non-null  float64
#  8   Distance_to_City_Center         10000 non-null  float64
#  9   Neighborhood_Quality_Score      10000 non-null  int64
#  10  Crime_Rate_Index                10000 non-null  float64
#  11  Nearby_School_Rating            10000 non-null  float64
#  12  Hospital_Proximity_km           10000 non-null  float64
#  13  Shopping_Center_Proximity_km    10000 non-null  float64
#  14  Public_Transport_Accessibility  10000 non-null  int64
#  15  Parking_Availability            10000 non-null  int64
#  16  Property_Type                   10000 non-null  object
#  17  Construction_Quality_Rating     10000 non-null  int64
#  18  Energy_Efficiency_Score         10000 non-null  float64
#  19  Water_Supply_Reliability        10000 non-null  int64
#  20  Electricity_Supply_Reliability  10000 non-null  int64
#  21  Internet_Availability_Score     10000 non-null  int64
#  22  Green_Space_Availability_Index  10000 non-null  float64
#  23  Flood_Risk_Index                10000 non-null  float64
#  24  Noise_Pollution_Level           10000 non-null  float64
#  25  Price                           10000 non-null  float64
#  26  Neighborhood_bin                10000 non-null  category
#  27  Age_bin                         10000 non-null  category
#  28  Distance_bin                    10000 non-null  category
# dtypes: category(3), float64(12), int64(12), object(2)
# memory usage: 2.0+ MB
# None
#        Property_Area     Bedrooms     Bathrooms        Floors    Year_Built  \
# count   10000.000000  10000.00000  10000.000000  10000.000000  10000.000000
# mean     2276.425061      2.87610      2.442800      1.884200   1997.043000
# std      1392.511528      1.51029      1.362319      0.879129     15.808806
# min       500.000000      1.00000      1.000000      1.000000   1970.000000
# 25%      1237.392579      2.00000      1.000000      1.000000   1983.000000
# 50%      1975.587909      3.00000      2.000000      2.000000   1997.000000
# 75%      2997.073207      4.00000      3.000000      2.000000   2011.000000
# max     12478.145506      6.00000      5.000000      4.000000   2024.000000
#
#        Property_Age      Lot_Size  Distance_to_City_Center  \
# count  10000.000000  10000.000000             10000.000000
# mean      27.957000   3384.453952                20.033634
# std       15.808806   1456.726518                11.475354
# min        1.000000    705.199318                 0.005200
# 25%       14.000000   2368.132778                10.096217
# 50%       28.000000   3131.557524                20.096249
# 75%       42.000000   4197.318944                29.973151
# max       55.000000   9980.726017                39.995004
#
#        Neighborhood_Quality_Score  Crime_Rate_Index  ...  \
# count                10000.000000      10000.000000  ...
# mean                     5.554800         55.525988  ...
# std                      2.869498         23.542633  ...
# min                      1.000000          5.374717  ...
# 25%                      3.000000         35.327993  ...
# 50%                      6.000000         55.423533  ...
# 75%                      8.000000         75.383014  ...
# max                     10.000000        100.000000  ...
#
#        Parking_Availability  Construction_Quality_Rating  \
# count          10000.000000                 10000.000000
# mean               0.703500                     5.491900
# std                0.456737                     2.869627
# min                0.000000                     1.000000
# 25%                0.000000                     3.000000
# 50%                1.000000                     5.000000
# 75%                1.000000                     8.000000
# max                1.000000                    10.000000
#
#        Energy_Efficiency_Score  Water_Supply_Reliability  \
# count             10000.000000              10000.000000
# mean                  5.523783                  5.457700
# std                   2.774792                  2.871487
# min                   1.000000                  1.000000
# 25%                   3.000000                  3.000000
# 50%                   5.588517                  5.000000
# 75%                   8.000000                  8.000000
# max                  10.000000                 10.000000
#
#        Electricity_Supply_Reliability  Internet_Availability_Score  \
# count                    10000.000000                  10000.00000
# mean                         5.485600                      5.50040
# std                          2.875486                      2.87413
# min                          1.000000                      1.00000
# 25%                          3.000000                      3.00000
# 50%                          5.000000                      6.00000
# 75%                          8.000000                      8.00000
# max                         10.000000                     10.00000
#
#        Green_Space_Availability_Index  Flood_Risk_Index  \
# count                    10000.000000      10000.000000
# mean                        44.678263         55.140929
# std                         24.001130         25.896884
# min                          0.000000          0.000000
# 25%                         25.674192         35.022099
# 50%                         44.639967         55.565598
# 75%                         63.193884         75.765089
# max                        100.000000        100.000000
#
#        Noise_Pollution_Level         Price
# count           10000.000000  1.000000e+04
# mean               56.599346  1.002539e+07
# std                 8.838504  5.869033e+06
# min                29.741203  5.000000e+05
# 25%                50.246967  5.706841e+06
# 50%                56.508197  8.777037e+06
# 75%                63.068874  1.321061e+07
# max                82.112373  5.588905e+07
#
# [8 rows x 24 columns]
# Property_Area                     0
# Bedrooms                          0
# Bathrooms                         0
# Floors                            0
# Year_Built                        0
# Property_Age                      0
# Renovation_Status                 0
# Lot_Size                          0
# Distance_to_City_Center           0
# Neighborhood_Quality_Score        0
# Crime_Rate_Index                  0
# Nearby_School_Rating              0
# Hospital_Proximity_km             0
# Shopping_Center_Proximity_km      0
# Public_Transport_Accessibility    0
# Parking_Availability              0
# Property_Type                     0
# Construction_Quality_Rating       0
# Energy_Efficiency_Score           0
# Water_Supply_Reliability          0
# Electricity_Supply_Reliability    0
# Internet_Availability_Score       0
# Green_Space_Availability_Index    0
# Flood_Risk_Index                  0
# Noise_Pollution_Level             0
# Price                             0
# Neighborhood_bin                  0
# Age_bin                           0
# Distance_bin                      0
# dtype: int64

# %%
sns.histplot(df["Price"], kde=True)
plt.title("Distribution of House Prices")
plt.show()
print(df["Price"].skew())
# Out:
# 1.1047004945340464

# %%
plt.scatter(df["Property_Area"], df["Price"])
plt.xlabel("Property Area")
plt.ylabel("Price")
plt.title("Area vs Price")
plt.show()

# %%
plt.scatter(df["Distance_to_City_Center"], df["Price"])
plt.xlabel("Distance to City Center")
plt.ylabel("Price")
plt.title("Distance vs Price")
plt.show()

# %%
plt.scatter(df["Crime_Rate_Index"], df["Price"])
plt.xlabel("Crime Rate")
plt.ylabel("Price")
plt.title("Crime Rate vs Price")
plt.show()

# %%
plt.figure()
sns.boxplot(df["Price"])
plt.title("Boxplot of Price (Outliers)")
plt.show()

# %%
#One-Hot Encoding Used 

cat_col = df_new.select_dtypes(include='object').columns
df_new = pd.get_dummies(df_new , columns = cat_col , drop_first = True)
#  drop-first Function takes 1 value of the categorical column as a 'reference'

df_new
# Out:
#       Property_Area  Bedrooms  Bathrooms  Floors  Year_Built  Property_Age  \
# 0       2684.821829         5          5       2        2018             7
# 1       1772.507662         1          1       1        1970            55
# 2       1655.959623         2          1       1        2015            10
# 3       1655.979127         1          1       1        1976            49
# 4       4879.446067         3          2       3        1999            26
# ...             ...       ...        ...     ...         ...           ...
# 9995    2302.741825         2          2       1        1994            31
# 9996    1373.561786         3          3       2        1994            31
# 9997    1191.319333         2          2       2        2022             3
# 9998    2811.384485         6          5       1        1970            55
# 9999     802.612274         1          1       2        1972            53
#
#          Lot_Size  Distance_to_City_Center  Neighborhood_Quality_Score  \
# 0     3776.225833                33.354414                           8
# 1     3343.248191                21.896193                           5
# 2     2856.909759                25.358405                           2
# 3     2998.753552                22.062582                           6
# 4     5373.625371                22.449431                           2
# ...           ...                      ...                         ...
# 9995  3766.541599                10.708116                           9
# 9996  2271.349068                11.949866                           4
# 9997  2748.265662                23.944225                           2
# 9998  4906.370154                 7.170758                           8
# 9999  1385.413483                18.927714                           7
#
#       Crime_Rate_Index  ...  Water_Supply_Reliability  \
# 0            35.239294  ...                         4
# 1            63.487365  ...                         3
# 2            83.749235  ...                         3
# 3            55.247941  ...                         9
# 4            77.985565  ...                         1
# ...                ...  ...                       ...
# 9995         30.634170  ...                         7
# 9996         58.222542  ...                         9
# 9997         84.525293  ...                        10
# 9998         35.927063  ...                         1
# 9999         41.347532  ...                        10
#
#       Electricity_Supply_Reliability  Internet_Availability_Score  \
# 0                                  5                            8
# 1                                  5                            8
# 2                                  5                           10
# 3                                  2                            4
# 4                                 10                            2
# ...                              ...                          ...
# 9995                               6                            2
# 9996                               3                            8
# 9997                               4                            8
# 9998                               8                            7
# 9999                               5                            9
#
#       Green_Space_Availability_Index  Flood_Risk_Index  Noise_Pollution_Level  \
# 0                          51.585174         42.269855              51.872234
# 1                          36.729241         66.331214              66.489083
# 2                          20.020779         79.023068              68.119671
# 3                          40.894197         53.745498              60.449037
# 4                          22.463846         86.873374              61.445164
# ...                              ...               ...                    ...
# 9995                       72.799026         36.744778              43.506769
# 9996                       25.805114         89.150722              66.396883
# 9997                        0.000000         91.177488              76.934267
# 9998                       54.362379         47.010666              53.486149
# 9999                       50.928561         48.380489              54.906311
#
#              Price  Renovation_Status_Yes  Property_Type_Independent House  \
# 0     1.203248e+07                   True                             True
# 1     7.425842e+06                  False                            False
# 2     5.734560e+06                  False                            False
# 3     8.258959e+06                   True                            False
# 4     2.128731e+07                  False                            False
# ...            ...                    ...                              ...
# 9995  1.173157e+07                  False                            False
# 9996  6.458641e+06                  False                            False
# 9997  4.891362e+06                  False                             True
# 9998  1.353664e+07                  False                            False
# 9999  4.605158e+06                   True                             True
#
#       Property_Type_Villa
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                    True
# ...                   ...
# 9995                 True
# 9996                 True
# 9997                False
# 9998                 True
# 9999                False
#
# [10000 rows x 27 columns]

# %%
# Clipping of Data Performed to Not Lose Data Points and Check Outliers

num_cols = [col for col in df_new.columns if df_new[col].nunique() > 2]
for col in num_cols:
    Q1 = df_new[col].quantile(0.25)
    Q3 = df_new[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    
    df_new[col] = df_new[col].clip(lower, upper)
df_new
# Out:
#       Property_Area  Bedrooms  Bathrooms  Floors  Year_Built  Property_Age  \
# 0       2684.821829         5          5     2.0        2018             7
# 1       1772.507662         1          1     1.0        1970            55
# 2       1655.959623         2          1     1.0        2015            10
# 3       1655.979127         1          1     1.0        1976            49
# 4       4879.446067         3          2     3.0        1999            26
# ...             ...       ...        ...     ...         ...           ...
# 9995    2302.741825         2          2     1.0        1994            31
# 9996    1373.561786         3          3     2.0        1994            31
# 9997    1191.319333         2          2     2.0        2022             3
# 9998    2811.384485         6          5     1.0        1970            55
# 9999     802.612274         1          1     2.0        1972            53
#
#          Lot_Size  Distance_to_City_Center  Neighborhood_Quality_Score  \
# 0     3776.225833                33.354414                           8
# 1     3343.248191                21.896193                           5
# 2     2856.909759                25.358405                           2
# 3     2998.753552                22.062582                           6
# 4     5373.625371                22.449431                           2
# ...           ...                      ...                         ...
# 9995  3766.541599                10.708116                           9
# 9996  2271.349068                11.949866                           4
# 9997  2748.265662                23.944225                           2
# 9998  4906.370154                 7.170758                           8
# 9999  1385.413483                18.927714                           7
#
#       Crime_Rate_Index  ...  Water_Supply_Reliability  \
# 0            35.239294  ...                         4
# 1            63.487365  ...                         3
# 2            83.749235  ...                         3
# 3            55.247941  ...                         9
# 4            77.985565  ...                         1
# ...                ...  ...                       ...
# 9995         30.634170  ...                         7
# 9996         58.222542  ...                         9
# 9997         84.525293  ...                        10
# 9998         35.927063  ...                         1
# 9999         41.347532  ...                        10
#
#       Electricity_Supply_Reliability  Internet_Availability_Score  \
# 0                                  5                            8
# 1                                  5                            8
# 2                                  5                           10
# 3                                  2                            4
# 4                                 10                            2
# ...                              ...                          ...
# 9995                               6                            2
# 9996                               3                            8
# 9997                               4                            8
# 9998                               8                            7
# 9999                               5                            9
#
#       Green_Space_Availability_Index  Flood_Risk_Index  Noise_Pollution_Level  \
# 0                          51.585174         42.269855              51.872234
# 1                          36.729241         66.331214              66.489083
# 2                          20.020779         79.023068              68.119671
# 3                          40.894197         53.745498              60.449037
# 4                          22.463846         86.873374              61.445164
# ...                              ...               ...                    ...
# 9995                       72.799026         36.744778              43.506769
# 9996                       25.805114         89.150722              66.396883
# 9997                        0.000000         91.177488              76.934267
# 9998                       54.362379         47.010666              53.486149
# 9999                       50.928561         48.380489              54.906311
#
#              Price  Renovation_Status_Yes  Property_Type_Independent House  \
# 0     1.203248e+07                   True                             True
# 1     7.425842e+06                  False                            False
# 2     5.734560e+06                  False                            False
# 3     8.258959e+06                   True                            False
# 4     2.128731e+07                  False                            False
# ...            ...                    ...                              ...
# 9995  1.173157e+07                  False                            False
# 9996  6.458641e+06                  False                            False
# 9997  4.891362e+06                  False                             True
# 9998  1.353664e+07                  False                            False
# 9999  4.605158e+06                   True                             True
#
#       Property_Type_Villa
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                    True
# ...                   ...
# 9995                 True
# 9996                 True
# 9997                False
# 9998                 True
# 9999                False
#
# [10000 rows x 27 columns]

# %%
df_new.to_csv("Final_Data.csv" , index = False)

# %%
x = df_new.drop('Price' , axis=1)
y = df_new['Price']

# %%
x_train  , x_test , y_train , y_test = train_test_split( x , y , test_size = 0.4 , random_state = 42)

# %%
x_train , x_test , y_train , y_test
# Out:
# (array([[ 1.57552083,  1.87245212,  0.20581043, ...,  0.        ,
#           0.        ,  1.        ],
#         [-0.38626254,  0.40577944,  0.20581043, ...,  0.        ,
#           0.        ,  0.        ],
#         [-1.33004552, -0.3275569 , -1.07649757, ...,  0.        ,
#           0.        ,  0.        ],
#         ...,
#         [ 0.13160555, -1.06089324, -1.07649757, ...,  0.        ,
#           0.        ,  0.        ],
#         [ 2.55198841,  1.13911578,  0.20581043, ...,  0.        ,
#           1.        ,  0.        ],
#         [-0.93762239,  0.40577944,  0.20581043, ...,  0.        ,
#           0.        ,  1.        ]], shape=(6000, 19)),
#  array([[ 0.89065914,  1.14913083,  1.46116205, ...,  0.        ,
#           0.        ,  0.        ],
#         [-0.54166024, -1.05649456,  0.19471607, ...,  1.        ,
#           1.        ,  0.        ],
#         [ 1.09501127, -0.3212861 ,  1.46116205, ...,  1.        ,
#           1.        ,  0.        ],
#         ...,
#         [-0.0439221 , -0.3212861 ,  0.19471607, ...,  0.        ,
#           0.        ,  0.        ],
#         [-0.02601957, -1.05649456,  0.19471607, ...,  1.        ,
#           0.        ,  0.        ],
#         [-0.46291358, -1.05649456, -1.07172991, ...,  1.        ,
#           1.        ,  0.        ]], shape=(4000, 19)),
#  9761    1.997209e+07
#  3159    5.875217e+06
#  1489    3.057031e+06
#  2987    7.321557e+06
#  812     6.169848e+06
#              ...
#  5734    7.633417e+06
#  5191    1.008635e+07
#  5390    9.747133e+06
#  860     2.359444e+07
#  7270    6.617757e+06
#  Name: Price, Length: 6000, dtype: float64,
#  6252    1.539210e+07
#  4684    7.483842e+06
#  1731    1.593588e+07
#  4742    5.000000e+05
#  4521    1.924866e+07
#              ...
#  4209    3.483570e+06
#  681     1.293008e+07
#  434     9.449028e+06
#  9309    1.013777e+07
#  4824    7.749048e+06
#  Name: Price, Length: 4000, dtype: float64)

# %%
#Although all Columns are Already Numeric , Dummy Columns (Encoded Columns) are NOT to be Scaled

num_cols = x_train.select_dtypes(include=['int64', 'float64']).columns
num_cols = [col for col in num_cols if x_train[col].nunique() > 2]
num_cols
# Out:
# ['Property_Area',
#  'Bedrooms',
#  'Bathrooms',
#  'Floors',
#  'Year_Built',
#  'Property_Age',
#  'Lot_Size',
#  'Distance_to_City_Center',
#  'Neighborhood_Quality_Score',
#  'Crime_Rate_Index',
#  'Nearby_School_Rating',
#  'Hospital_Proximity_km',
#  'Shopping_Center_Proximity_km',
#  'Public_Transport_Accessibility',
#  'Construction_Quality_Rating',
#  'Energy_Efficiency_Score',
#  'Water_Supply_Reliability',
#  'Electricity_Supply_Reliability',
#  'Internet_Availability_Score',
#  'Green_Space_Availability_Index',
#  'Flood_Risk_Index',
#  'Noise_Pollution_Level']

# %%
#Scaling The Data
scale = StandardScaler()
x_train[num_cols] = scale.fit_transform(x_train[num_cols])
x_test[num_cols] = scale.fit_transform(x_test[num_cols])

# %%
#Model of Linear Regression Made

model = LinearRegression()

# %%
#Backward Elimination Used to select Features 

sfs = SequentialFeatureSelector(model,n_features_to_select=19, direction='backward')

# %%
sfs.fit_transform(x_train , y_train)
# Out:
# array([[ 1.57552083,  1.87245212,  0.20581043, ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.38626254,  0.40577944,  0.20581043, ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.33004552, -0.3275569 , -1.07649757, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.13160555, -1.06089324, -1.07649757, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 2.55198841,  1.13911578,  0.20581043, ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.93762239,  0.40577944,  0.20581043, ...,  0.        ,
#          0.        ,  1.        ]], shape=(6000, 19))

# %%
x_train = sfs.transform(x_train)
x_test = sfs.transform(x_test)

# %%
selected_features = x.columns[sfs.get_support()]
print(selected_features)
# Out:
# Index(['Property_Area', 'Bathrooms', 'Floors', 'Property_Age',
#        'Distance_to_City_Center', 'Neighborhood_Quality_Score',
#        'Crime_Rate_Index', 'Nearby_School_Rating', 'Hospital_Proximity_km',
#        'Public_Transport_Accessibility', 'Parking_Availability',
#        'Construction_Quality_Rating', 'Energy_Efficiency_Score',
#        'Green_Space_Availability_Index', 'Flood_Risk_Index',
#        'Noise_Pollution_Level', 'Renovation_Status_Yes',
#        'Property_Type_Independent House', 'Property_Type_Villa'],
#       dtype='object')

# %%
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([15000278.32701142,  7397052.88658718, 14638712.7772962 , ...,
#         8473499.55163348, 10662775.40068327,  7673338.64085076],
#       shape=(4000,))

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)

print("RMSE:", rmse)
print("MAE:", mae)

mean_y = y.mean()

print("Mean of target:", mean_y)
print("RMSE %:", (rmse / mean_y) * 100)
print("MAE %:", (mae / mean_y) * 100)

print("Min:", y.min())
print("Max:", y.max())
print("Mean:", y.mean())
# Out:
# RMSE: 804198.9105043074
# MAE: 638396.7506659669
# Mean of target: 9929421.789114533
# RMSE %: 8.09915146706667
# MAE %: 6.429344671064645
# Min: 500000.0
# Max: 24466254.311061855
# Mean: 9929421.789114533

# %%
r2 = r2_score(y_test , y_pred) 
print("R2 Score : " , r2)
# Out:
# R2 Score :  0.9788186488648342

# %%
y_train_pred = model.predict(x_train)

train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_pred)

print("Train R2:", train_r2)
print("Test R2:", test_r2)
# Out:
# Train R2: 0.9787682962064621
# Test R2: 0.9788186488648342

# %%
r2 = r2_score(x_train , y_train) 
print("R2 Train Score : " , r2)

# %%
plt.figure(figsize=(7,5))

# Scatter points
plt.scatter(y_test, y_pred, alpha=0.3 , label='Actual DataPoints')

# Create regression line
m, b = np.polyfit(y_test, y_pred, 1)
line = m * y_test + b

# Sort values for smooth line
sorted_idx = np.argsort(y_test)

plt.plot(y_test.iloc[sorted_idx], line.iloc[sorted_idx] , color= 'red' , linewidth = 3 , label='Best Fit Line')

plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Regression Line with Scatter Points")
plt.legend()
plt.show()

# %%
residuals = y_test - y_pred

plt.scatter(y_pred, residuals, alpha=0.3)
plt.axhline(y=0, color='red')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
sns.histplot(residuals, kde=True)
plt.title("Residual Distribution")
plt.show()

# %%
coeff = pd.DataFrame({
    "Feature": selected_features,
    "Coefficient": model.coef_
}).sort_values(by="Coefficient", ascending=True)

coeff
# Out:
#                             Feature   Coefficient
# 6                  Crime_Rate_Index -3.337569e+05
# 14                 Flood_Risk_Index -2.404077e+05
# 4           Distance_to_City_Center -2.267584e+05
# 3                      Property_Age -1.488970e+05
# 15            Noise_Pollution_Level -4.564295e+04
# 8             Hospital_Proximity_km -2.019285e+04
# 13   Green_Space_Availability_Index  6.201262e+04
# 2                            Floors  6.254548e+04
# 7              Nearby_School_Rating  8.532597e+04
# 9    Public_Transport_Accessibility  9.209629e+04
# 12          Energy_Efficiency_Score  1.241263e+05
# 1                         Bathrooms  1.417555e+05
# 5        Neighborhood_Quality_Score  1.513522e+05
# 11      Construction_Quality_Rating  1.686656e+05
# 10             Parking_Availability  3.127448e+05
# 17  Property_Type_Independent House  3.347389e+05
# 16            Renovation_Status_Yes  3.894235e+05
# 18              Property_Type_Villa  9.608894e+05
# 0                     Property_Area  5.283616e+06

# %%
coeff_sorted = coeff.sort_values(by="Coefficient", ascending=False)

print("Top Positive Features:")
print(coeff_sorted.head())

print("Top Negative Features:")
print(coeff_sorted.tail())
# Out:
# Top Positive Features:
#                             Feature   Coefficient
# 0                     Property_Area  5.283616e+06
# 18              Property_Type_Villa  9.608894e+05
# 16            Renovation_Status_Yes  3.894235e+05
# 17  Property_Type_Independent House  3.347389e+05
# 10             Parking_Availability  3.127448e+05
# Top Negative Features:
#                     Feature    Coefficient
# 15    Noise_Pollution_Level  -45642.951363
# 3              Property_Age -148896.999002
# 4   Distance_to_City_Center -226758.374950
# 14         Flood_Risk_Index -240407.708783
# 6          Crime_Rate_Index -333756.948513
